# %% [markdown]
# Time Series Decompositon

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# Step 1: Read the dataset

# %%
import pandas as pd
df = pd.read_csv('AirPassengers.csv', index_col='Month', parse_dates=True)
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# Step 2: Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
df.isna().sum()
# Out:
# Passengers    0
# dtype: int64

# %% [markdown]
# Visualize the time series

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(10,5))
plt.plot(df['Passengers'])
plt.xlabel('Month')
plt.ylabel('Number of Air Passengers')
plt.title('Air Passengers')
plt.grid()
plt.show()

# %% [markdown]
# Decompose the time series - Multiplicative model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
Q = seasonal_decompose(x=df['Passengers'], model='multiplicative')
Q.plot()

# %% [markdown]
# Plot the Trend

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Passengers'], label='Observed')
plt.plot(Q.trend, label='Trend')
plt.xlabel('Month')
plt.ylabel('Number of Air Passengers')
plt.title('Trend Analysis')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Plot the Seasonal Graph

# %%
plt.figure(figsize=(10, 5))
plt.plot(Q.seasonal)
plt.xlabel('Month')
plt.ylabel('Number of Air Passengers')
plt.title('Seasonal Analysis')
plt.grid()
plt.show()

# %% [markdown]
# Plot the residuals

# %%
plt.figure(figsize=(10, 5))
plt.plot(Q.resid)
plt.xlabel('Month')
plt.ylabel('Number of Air Passengers')
plt.title('Residual Analysis')
plt.grid()
plt.show()

# %% [markdown]
# Time Series Forecasting

# %%
# %pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in d:\ml wakad\repository\venv\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (2.2.1)
# Requirement already satisfied: scikit-learn>=0.22 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (1.4.1.post1)
# Requirement already satisfied: scipy>=1.3.2 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (1.12.0)
# Requirement already satisfied: statsmodels>=0.13.2 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: urllib3 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (2.2.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (69.5.1)
# Requirement already satisfied: packaging>=17.1 in d:\ml wakad\repository\venv\lib\site-packages (from pmdarima) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ml wakad\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\ml wakad\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\ml wakad\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\ml wakad\repository\venv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.3.0)
# Requirement already satisfied: patsy>=0.5.4 in d:\ml wakad\repository\venv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in d:\ml wakad\repository\venv\lib\site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Restart kernel and run all cells
# ARIMA - Auto Regressive Integrated Moving Average

# %%
from pmdarima.arima import auto_arima 
model = auto_arima(df['Passengers'], m=12, seasonal=True)

# %%
model.order
# Out:
# (2, 1, 1)

# %% [markdown]
# Get the forecast for 4 years

# %% [markdown]
# 3 years = 3*12 month = 48 months

# %%
forecast, conf = model.predict(n_periods=48, return_conf_int=True)

# %%
forecast
# Out:
# 1961-01-01    445.634934
# 1961-02-01    420.395042
# 1961-03-01    449.198378
# 1961-04-01    491.840023
# 1961-05-01    503.394565
# 1961-06-01    566.862550
# 1961-07-01    654.260284
# 1961-08-01    638.597604
# 1961-09-01    540.883864
# 1961-10-01    494.126748
# 1961-11-01    423.332841
# 1961-12-01    465.507712
# 1962-01-01    479.291026
# 1962-02-01    454.177037
# 1962-03-01    483.087203
# 1962-04-01    525.819493
# 1962-05-01    537.450950
# 1962-06-01    600.984197
# 1962-07-01    688.437307
# 1962-08-01    672.821614
# 1962-09-01    575.147743
# 1962-10-01    528.424456
# 1962-11-01    457.659254
# 1962-12-01    499.858481
# 1963-01-01    513.662462
# 1963-02-01    488.566008
# 1963-03-01    517.491053
# 1963-04-01    560.235969
# 1963-05-01    571.878138
# 1963-06-01    635.420475
# 1963-07-01    722.881298
# 1963-08-01    707.272149
# 1963-09-01    609.603831
# 1963-10-01    562.885256
# 1963-11-01    492.124052
# 1963-12-01    534.326671
# 1964-01-01    548.133530
# 1964-02-01    523.039519
# 1964-03-01    551.966636
# 1964-04-01    594.713311
# 1964-05-01    606.356972
# 1964-06-01    669.900575
# 1964-07-01    757.362472
# 1964-08-01    741.754234
# 1964-09-01    644.086690
# 1964-10-01    597.368772
# 1964-11-01    526.608124
# 1964-12-01    568.811216
# Freq: MS, dtype: float64

# %%
conf
# Out:
# array([[423.34475094, 467.92511658],
#        [394.23518302, 446.55490116],
#        [419.83140846, 478.56534829],
#        [460.37587373, 523.30417201],
#        [470.37999658, 536.40913406],
#        [532.69880168, 601.02629843],
#        [619.22055901, 689.30000963],
#        [602.87921604, 674.31599104],
#        [504.63055231, 577.13717502],
#        [457.44514984, 530.80834643],
#        [386.3030106 , 460.36267117],
#        [428.19044593, 502.82497842],
#        [433.49653884, 525.08551376],
#        [405.10774907, 503.24632483],
#        [431.15437638, 535.02002912],
#        [471.83916844, 579.79981805],
#        [481.87209035, 593.02980929],
#        [544.15500525, 657.81338881],
#        [630.60709073, 746.26752372],
#        [614.17741433, 731.46581272],
#        [515.83056926, 634.46491613],
#        [468.54219966, 588.30671331],
#        [397.2952923 , 518.02321528],
#        [439.07790127, 560.63906114],
#        [446.32509131, 580.99983223],
#        [418.31603539, 558.81598086],
#        [444.62194643, 590.36015987],
#        [485.39943994, 635.07249774],
#        [495.4479624 , 648.30831366],
#        [557.69634351, 713.1446065 ],
#        [644.08397085, 801.67862509],
#        [627.57137805, 786.97291922],
#        [529.13050031, 690.07716124],
#        [481.74160891, 644.02890374],
#        [410.39065083, 573.85745237],
#        [452.0675645 , 616.58577818],
#        [460.16731335, 636.09974732],
#        [432.31663053, 613.7624076 ],
#        [458.72382463, 645.20944831],
#        [499.51205735, 689.91456386],
#        [509.52700787, 703.18693582],
#        [571.71195467, 768.08919502],
#        [658.01786667, 856.70707742],
#        [641.41211585, 842.09635257],
#        [542.87114407, 745.30223547],
#        [495.37812565, 699.35941749],
#        [423.92089492, 629.29535245],
#        [465.49060676, 672.13182506]])

# %%
df_forecast = forecast.to_frame()
df_forecast.columns = ['Forecast']
df_forecast
# Out:
#               Forecast
# 1961-01-01  445.634934
# 1961-02-01  420.395042
# 1961-03-01  449.198378
# 1961-04-01  491.840023
# 1961-05-01  503.394565
# 1961-06-01  566.862550
# 1961-07-01  654.260284
# 1961-08-01  638.597604
# 1961-09-01  540.883864
# 1961-10-01  494.126748
# 1961-11-01  423.332841
# 1961-12-01  465.507712
# 1962-01-01  479.291026
# 1962-02-01  454.177037
# 1962-03-01  483.087203
# 1964-05-01  606.356972  509.527008  703.186936
# 1964-06-01  669.900575  571.711955  768.089195
# 1964-07-01  757.362472  658.017867  856.707077
# 1964-08-01  741.754234  641.412116  842.096353
# 1964-09-01  644.086690  542.871144  745.302235
# 1964-10-01  597.368772  495.378126  699.359417
# 1964-11-01  526.608124  423.920895  629.295352
# 1964-12-01  568.811216  465.490607  672.131825

# %%
df_forecast = df_forecast.apply(round)
df_forecast
# Out:
#             Forecast  Lower  Upper
# 1961-01-01     446.0  423.0  468.0
# 1961-02-01     420.0  394.0  447.0
# 1961-03-01     449.0  420.0  479.0
# 1961-04-01     492.0  460.0  523.0
# 1961-05-01     503.0  470.0  536.0
# 1961-06-01     567.0  533.0  601.0
# 1961-07-01     654.0  619.0  689.0
# 1961-08-01     639.0  603.0  674.0
# 1961-09-01     541.0  505.0  577.0
# 1961-10-01     494.0  457.0  531.0
# 1961-11-01     423.0  386.0  460.0
# 1961-12-01     466.0  428.0  503.0
# 1962-01-01     479.0  433.0  525.0
# 1962-02-01     454.0  405.0  503.0
# 1962-03-01     483.0  431.0  535.0
# 1962-04-01     526.0  472.0  580.0
# 1962-05-01     537.0  482.0  593.0
# 1962-06-01     601.0  544.0  658.0
# 1962-07-01     688.0  631.0  746.0
# 1962-08-01     673.0  614.0  731.0
# 1962-09-01     575.0  516.0  634.0
# 1962-10-01     528.0  469.0  588.0
# 1962-11-01     458.0  397.0  518.0
# 1962-12-01     500.0  439.0  561.0
# 1963-01-01     514.0  446.0  581.0
# 1963-02-01     489.0  418.0  559.0
# 1963-03-01     517.0  445.0  590.0
# 1963-04-01     560.0  485.0  635.0
# 1963-05-01     572.0  495.0  648.0
# 1963-06-01     635.0  558.0  713.0
# 1963-07-01     723.0  644.0  802.0
# 1963-08-01     707.0  628.0  787.0
# 1963-09-01     610.0  529.0  690.0
# 1963-10-01     563.0  482.0  644.0
# 1963-11-01     492.0  410.0  574.0
# 1963-12-01     534.0  452.0  617.0
# 1964-01-01     548.0  460.0  636.0
# 1964-02-01     523.0  432.0  614.0
# 1964-03-01     552.0  459.0  645.0
# 1964-04-01     595.0  500.0  690.0
# 1964-05-01     606.0  510.0  703.0
# 1964-06-01     670.0  572.0  768.0
# 1964-07-01     757.0  658.0  857.0
# 1964-08-01     742.0  641.0  842.0
# 1964-09-01     644.0  543.0  745.0
# 1964-10-01     597.0  495.0  699.0
# 1964-11-01     527.0  424.0  629.0
# 1964-12-01     569.0  465.0  672.0

# %% [markdown]
# Save above result to csv

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Passengers'], label='Observed')
plt.plot(df_forecast['Forecast'], label='Forecast')
plt.fill_between(x=df_forecast.index, 
                 y1=df_forecast['Lower'], 
                 y2=df_forecast['Upper'], 
                 alpha=0.7, color='gray', label='Confidence interval')
plt.xlabel('Month')
plt.ylabel('Number of Air Passengers')
plt.title('Forecast Sheet')
plt.legend()
plt.grid()
plt.show()
